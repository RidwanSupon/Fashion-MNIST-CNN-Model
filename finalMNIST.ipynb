# %%
# ==========================================================
# 1 IMPORT LIBRARIES
# ==========================================================

import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

from sklearn.metrics import classification_report, confusion_matrix


# ==========================================================
# 2 LOAD DATASET
# ==========================================================

fashion_mnist = keras.datasets.fashion_mnist
(X_train, y_train), (X_test, y_test) = fashion_mnist.load_data()


# ==========================================================
# 3 PREPROCESSING
# ==========================================================

# Normalize pixel values
X_train = X_train / 255.0
X_test = X_test / 255.0

# reshape for CNN
X_train = X_train.reshape(-1,28,28,1)
X_test = X_test.reshape(-1,28,28,1)

# Resize images (improvement)
X_train = tf.image.resize(X_train,(32,32))
X_test = tf.image.resize(X_test,(32,32))


# ==========================================================
# 4 DATA AUGMENTATION
# ==========================================================

data_augmentation = keras.Sequential([

    layers.RandomRotation(0.15),
    layers.RandomZoom(0.2),
    layers.RandomTranslation(0.15,0.15)

])


# ==========================================================
# 5 IMPROVED CNN MODEL
# ==========================================================

model = keras.Sequential([

    keras.Input(shape=(32,32,1)),

    data_augmentation,

    # -------------------------
    # BLOCK 1
    # -------------------------
    layers.Conv2D(
        32,(3,3),
        padding="same",
        activation="relu",
        kernel_regularizer=keras.regularizers.l2(0.001)
    ),
    layers.BatchNormalization(),

    layers.Conv2D(
        32,(3,3),
        activation="relu"
    ),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.25),


    # -------------------------
    # BLOCK 2
    # -------------------------
    layers.Conv2D(
        64,(3,3),
        padding="same",
        activation="relu"
    ),
    layers.BatchNormalization(),

    layers.Conv2D(
        64,(3,3),
        activation="relu"
    ),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.3),


    # -------------------------
    # BLOCK 3
    # -------------------------
    layers.Conv2D(
        128,(3,3),
        padding="same",
        activation="relu"
    ),
    layers.BatchNormalization(),

    layers.Conv2D(
        128,(3,3),
        activation="relu"
    ),
    layers.BatchNormalization(),

    layers.MaxPooling2D(),
    layers.Dropout(0.35),


    # Global feature pooling
    layers.GlobalAveragePooling2D(),


    # Dense layers
    layers.Dense(128,activation="relu"),
    layers.BatchNormalization(),
    layers.Dropout(0.5),

    layers.Dense(10,activation="softmax")

])


# ==========================================================
# 6 COMPILE MODEL
# ==========================================================

model.compile(

    optimizer=keras.optimizers.Adam(learning_rate=0.0005),

    loss="sparse_categorical_crossentropy",

    metrics=["accuracy"]

)

model.summary()


# ==========================================================
# 7 CALLBACKS
# ==========================================================

callbacks = [

    keras.callbacks.EarlyStopping(
        monitor="val_loss",
        patience=6,
        restore_best_weights=True
    ),

    keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss",
        factor=0.3,
        patience=3
    )

]


# ==========================================================
# 8 TRAIN MODEL
# ==========================================================

history = model.fit(

    X_train,
    y_train,

    epochs=50,

    batch_size=32,

    validation_split=0.15,

    callbacks=callbacks

)


# ==========================================================
# 9 EVALUATION
# ==========================================================

test_loss, test_acc = model.evaluate(X_test, y_test)

print("\nTest Accuracy:", test_acc)


# ==========================================================
# 10 PREDICTION
# ==========================================================

y_pred_prob = model.predict(X_test)

y_pred = np.argmax(y_pred_prob,axis=1)


# ==========================================================
# 11 CLASSIFICATION REPORT
# ==========================================================

class_names = [

"T-shirt/top",
"Trouser",
"Pullover",
"Dress",
"Coat",
"Sandal",
"Shirt",
"Sneaker",
"Bag",
"Ankle Boot"

]

print("\nClassification Report:\n")

print(classification_report(y_test,y_pred,target_names=class_names))


# ==========================================================
# 12 CONFUSION MATRIX
# ==========================================================

cm = confusion_matrix(y_test,y_pred)

plt.figure(figsize=(8,6))

sns.heatmap(cm,annot=True,fmt="d",cmap="Blues")

plt.title("Confusion Matrix")

plt.xlabel("Predicted")

plt.ylabel("Actual")

plt.show()


# ==========================================================
# 13 TRAINING GRAPHS
# ==========================================================

plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])

plt.title("Model Accuracy")
plt.ylabel("Accuracy")
plt.xlabel("Epoch")
plt.legend(["Train","Validation"])

plt.show()


plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])

plt.title("Model Loss")
plt.ylabel("Loss")
plt.xlabel("Epoch")
plt.legend(["Train","Validation"])

plt.show()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 ━━━━━━━━━━━━━━━━━━━━ 0s 1us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)         │ (None, 32, 32, 1)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d (Conv2D)                 │ (None, 32, 32, 32)     │           320 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 32, 32, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 30, 30, 32)     │         9,248 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 30, 30, 32)     │           128 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 15, 32)     │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 15, 15, 64)     │        18,496 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 15, 15, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_3 (Conv2D)               │ (None, 13, 13, 64)     │        36,928 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 13, 13, 64)     │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 6, 6, 64)       │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_4 (Conv2D)               │ (None, 6, 6, 128)      │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 6, 6, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_5 (Conv2D)               │ (None, 4, 4, 128)      │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 4, 4, 128)      │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_2 (MaxPooling2D)  │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 2, 2, 128)      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 128)            │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │        16,512 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 10)             │         1,290 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 306,538 (1.17 MB)
#  Trainable params: 305,386 (1.16 MB)
#  Non-trainable params: 1,152 (4.50 KB)
# Epoch 1/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 374s 231ms/step - accuracy: 0.4323 - loss: 1.7663 - val_accuracy: 0.6913 - val_loss: 0.7834 - learning_rate: 5.0000e-04
# Epoch 2/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 383s 232ms/step - accuracy: 0.6766 - loss: 0.8921 - val_accuracy: 0.7677 - val_loss: 0.6166 - learning_rate: 5.0000e-04
# Epoch 3/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 375s 235ms/step - accuracy: 0.7364 - loss: 0.7423 - val_accuracy: 0.8086 - val_loss: 0.5164 - learning_rate: 5.0000e-04
# Epoch 4/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 376s 232ms/step - accuracy: 0.7663 - loss: 0.6619 - val_accuracy: 0.8142 - val_loss: 0.5036 - learning_rate: 5.0000e-04
# Epoch 5/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 368s 231ms/step - accuracy: 0.7801 - loss: 0.6187 - val_accuracy: 0.8321 - val_loss: 0.4525 - learning_rate: 5.0000e-04
# Epoch 6/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 387s 234ms/step - accuracy: 0.7969 - loss: 0.5739 - val_accuracy: 0.7904 - val_loss: 0.5248 - learning_rate: 5.0000e-04
# Epoch 7/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 366s 230ms/step - accuracy: 0.8066 - loss: 0.5477 - val_accuracy: 0.8404 - val_loss: 0.4327 - learning_rate: 5.0000e-04
# Epoch 8/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 366s 230ms/step - accuracy: 0.8112 - loss: 0.5281 - val_accuracy: 0.8494 - val_loss: 0.4097 - learning_rate: 5.0000e-04
# Epoch 9/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 366s 229ms/step - accuracy: 0.8213 - loss: 0.5124 - val_accuracy: 0.8226 - val_loss: 0.4508 - learning_rate: 5.0000e-04
# Epoch 10/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 383s 230ms/step - accuracy: 0.8238 - loss: 0.4983 - val_accuracy: 0.8297 - val_loss: 0.4473 - learning_rate: 5.0000e-04
# Epoch 11/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 365s 229ms/step - accuracy: 0.8308 - loss: 0.4783 - val_accuracy: 0.8009 - val_loss: 0.5112 - learning_rate: 5.0000e-04
# Epoch 12/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 389s 234ms/step - accuracy: 0.8410 - loss: 0.4568 - val_accuracy: 0.8474 - val_loss: 0.4073 - learning_rate: 1.5000e-04
# Epoch 13/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 373s 234ms/step - accuracy: 0.8485 - loss: 0.4231 - val_accuracy: 0.8526 - val_loss: 0.3931 - learning_rate: 1.5000e-04
# Epoch 14/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 373s 234ms/step - accuracy: 0.8507 - loss: 0.4261 - val_accuracy: 0.8602 - val_loss: 0.3685 - learning_rate: 1.5000e-04
# Epoch 15/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 366s 230ms/step - accuracy: 0.8544 - loss: 0.4169 - val_accuracy: 0.8549 - val_loss: 0.3745 - learning_rate: 1.5000e-04
# Epoch 16/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 384s 241ms/step - accuracy: 0.8530 - loss: 0.4162 - val_accuracy: 0.8450 - val_loss: 0.3944 - learning_rate: 1.5000e-04
# Epoch 17/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 377s 236ms/step - accuracy: 0.8538 - loss: 0.4068 - val_accuracy: 0.8608 - val_loss: 0.3717 - learning_rate: 1.5000e-04
# Epoch 18/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 384s 241ms/step - accuracy: 0.8603 - loss: 0.3933 - val_accuracy: 0.8591 - val_loss: 0.3686 - learning_rate: 4.5000e-05
# Epoch 19/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 382s 239ms/step - accuracy: 0.8579 - loss: 0.3952 - val_accuracy: 0.8569 - val_loss: 0.3740 - learning_rate: 4.5000e-05
# Epoch 20/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 373s 234ms/step - accuracy: 0.8619 - loss: 0.3874 - val_accuracy: 0.8637 - val_loss: 0.3595 - learning_rate: 4.5000e-05
# Epoch 21/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 375s 230ms/step - accuracy: 0.8629 - loss: 0.3862 - val_accuracy: 0.8666 - val_loss: 0.3552 - learning_rate: 4.5000e-05
# Epoch 22/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 371s 233ms/step - accuracy: 0.8625 - loss: 0.3857 - val_accuracy: 0.8680 - val_loss: 0.3468 - learning_rate: 4.5000e-05
# Epoch 23/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 371s 232ms/step - accuracy: 0.8628 - loss: 0.3919 - val_accuracy: 0.8699 - val_loss: 0.3435 - learning_rate: 4.5000e-05
# Epoch 24/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 381s 232ms/step - accuracy: 0.8637 - loss: 0.3870 - val_accuracy: 0.8622 - val_loss: 0.3571 - learning_rate: 4.5000e-05
# Epoch 25/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 363s 227ms/step - accuracy: 0.8646 - loss: 0.3824 - val_accuracy: 0.8682 - val_loss: 0.3473 - learning_rate: 4.5000e-05
# Epoch 26/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 381s 227ms/step - accuracy: 0.8638 - loss: 0.3873 - val_accuracy: 0.8689 - val_loss: 0.3472 - learning_rate: 4.5000e-05
# Epoch 27/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 370s 232ms/step - accuracy: 0.8638 - loss: 0.3809 - val_accuracy: 0.8713 - val_loss: 0.3431 - learning_rate: 1.3500e-05
# Epoch 28/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 376s 228ms/step - accuracy: 0.8665 - loss: 0.3799 - val_accuracy: 0.8714 - val_loss: 0.3439 - learning_rate: 1.3500e-05
# Epoch 29/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 364s 229ms/step - accuracy: 0.8651 - loss: 0.3812 - val_accuracy: 0.8719 - val_loss: 0.3428 - learning_rate: 1.3500e-05
# Epoch 30/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 385s 230ms/step - accuracy: 0.8662 - loss: 0.3787 - val_accuracy: 0.8740 - val_loss: 0.3396 - learning_rate: 1.3500e-05
# Epoch 31/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 387s 234ms/step - accuracy: 0.8673 - loss: 0.3698 - val_accuracy: 0.8680 - val_loss: 0.3482 - learning_rate: 1.3500e-05
# Epoch 32/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 382s 234ms/step - accuracy: 0.8641 - loss: 0.3870 - val_accuracy: 0.8726 - val_loss: 0.3430 - learning_rate: 1.3500e-05
# Epoch 33/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 375s 235ms/step - accuracy: 0.8671 - loss: 0.3743 - val_accuracy: 0.8714 - val_loss: 0.3473 - learning_rate: 1.3500e-05
# Epoch 34/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 379s 233ms/step - accuracy: 0.8659 - loss: 0.3757 - val_accuracy: 0.8722 - val_loss: 0.3445 - learning_rate: 4.0500e-06
# Epoch 35/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 376s 236ms/step - accuracy: 0.8668 - loss: 0.3772 - val_accuracy: 0.8716 - val_loss: 0.3451 - learning_rate: 4.0500e-06
# Epoch 36/50
# 1594/1594 ━━━━━━━━━━━━━━━━━━━━ 377s 236ms/step - accuracy: 0.8687 - loss: 0.3693 - val_accuracy: 0.8714 - val_loss: 0.3451 - learning_rate: 4.0500e-06
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 52ms/step - accuracy: 0.8641 - loss: 0.3677
#
# Test Accuracy: 0.8668000102043152
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 16s 51ms/step
#
# Classification Report:
#
#               precision    recall  f1-score   support
#
#  T-shirt/top       0.84      0.79      0.81      1000
#      Trouser       0.99      0.98      0.99      1000
#     Pullover       0.86      0.80      0.83      1000
#        Dress       0.96      0.71      0.82      1000
#         Coat       0.82      0.76      0.79      1000
#       Sandal       0.98      0.97      0.97      1000
#        Shirt       0.53      0.78      0.63      1000
#      Sneaker       0.95      0.94      0.94      1000
#          Bag       0.97      0.99      0.98      1000
#   Ankle Boot       0.95      0.95      0.95      1000
#
#     accuracy                           0.87     10000
#    macro avg       0.88      0.87      0.87     10000
# weighted avg       0.88      0.87      0.87     10000
